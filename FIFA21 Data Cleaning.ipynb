# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading Data

# %%
pd.set_option('display.max_columns', None)
data = pd.read_csv('fifa21_raw_data.csv')
data.sample(10)
# Out:
# C:\Users\teopo\AppData\Local\Temp\ipykernel_27976\3190885902.py:2: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('fifa21_raw_data.csv')
#            ID              Name                         LongName  \
# 3774   230374    Deiverson Kaio  Deiverson Breno Kaio de Freitas
# 18430  243299         M. Nelson                   Michael Nelson
# 14281  240987         M. Cooper                   Michael Cooper
# 10422  238779        J. Verlaat                   Jesper Verlaat
# 8890   254319            Elliot               Elliot Gómez López
# 14775  232181       H. Adamczyk                  Hubert Adamczyk
# 3959   198970         J. Mensah                  Jonathan Mensah
# 15883  251028           K. Poku                       Kwame Poku
# 3361   214376        D. Andrade                   Darwin Andrade
# 4657   239645  M. de los Santos             Matías de los Santos
#
# ...

# %%
data.shape
# Out:
# (18979, 77)

# %% [markdown]
# #### There are missing values at 'Loan Date End' and 'Hits' columns.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Create a copy of dataframe

# %%
fifa = data.copy()
fifa.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %% [markdown]
# ### Club column
#
# #### Remove lines

# %%
fifa['Club'].unique()
# Out:
# array(['\n\n\n\nFC Barcelona', '\n\n\n\nJuventus',
#        '\n\n\n\nAtlético Madrid', '\n\n\n\nManchester City',
#        '\n\n\n\nParis Saint-Germain', '\n\n\n\nFC Bayern München',
#        '\n\n\n\nLiverpool', '\n\n\n\nReal Madrid', '\n\n\n\nChelsea',
#        '\n\n\n\nTottenham Hotspur', '\n\n\n\nInter', '\n\n\n\nNapoli',
#        '\n\n\n\nBorussia Dortmund', '\n\n\n\nManchester United',
#        '\n\n\n\nArsenal', '\n\n\n\nLazio', '\n\n\n\nLeicester City',
#        '\n\n\n\nBorussia Mönchengladbach', '\n\n\n\nReal Sociedad',
#        '\n\n\n\nAtalanta', '\n\n\n\nOlympique Lyonnais', '\n\n\n\nMilan',
#        '\n\n\n\nVillarreal CF', '\n\n\n\nRB Leipzig', '\n\n\n\nCagliari',
#        '\n\n\n\nAjax', '\n\n\n\nSL Benfica', '\n\n\n\nAS Monaco',
#        '\n\n\n\nWolverhampton Wanderers', '\n\n\n\nEverton',
#        '\n\n\n\nFiorentina', '\n\n\n\nFC Porto', '\n\n\n\nRC Celta',
#        '\n\n\n\nTorino', '\n\n\n\nSevilla FC', '\n\n\n\nGrêmio',
# ...

# %%
fifa['Club'] = fifa['Club'].str.strip()

# %%
fifa['Club'].unique()
# Out:
# array(['FC Barcelona', 'Juventus', 'Atlético Madrid', 'Manchester City',
#        'Paris Saint-Germain', 'FC Bayern München', 'Liverpool',
#        'Real Madrid', 'Chelsea', 'Tottenham Hotspur', 'Inter', 'Napoli',
#        'Borussia Dortmund', 'Manchester United', 'Arsenal', 'Lazio',
#        'Leicester City', 'Borussia Mönchengladbach', 'Real Sociedad',
#        'Atalanta', 'Olympique Lyonnais', 'Milan', 'Villarreal CF',
#        'RB Leipzig', 'Cagliari', 'Ajax', 'SL Benfica', 'AS Monaco',
#        'Wolverhampton Wanderers', 'Everton', 'Fiorentina', 'FC Porto',
#        'RC Celta', 'Torino', 'Sevilla FC', 'Grêmio', 'Real Betis', 'Roma',
#        'Newcastle United', 'Eintracht Frankfurt', 'Valencia CF',
#        'Medipol Başakşehir FK', 'Inter Miami', 'Bayer 04 Leverkusen',
#        'Levante UD', 'Crystal Palace', 'Athletic Club de Bilbao',
#        'Shanghai SIPG FC', 'VfL Wolfsburg',
#        'Guangzhou Evergrande Taobao FC', 'Al Shabab',
# ...

# %% [markdown]
# ### Contract Column
#
# #### This column contains some rows with values including 'On Loan' and 'Free'.

# %%
fifa['Contract'].unique()
# Out:
# array(['2004 ~ 2021', '2018 ~ 2022', '2014 ~ 2023', '2015 ~ 2023',
#        '2017 ~ 2022', '2017 ~ 2023', '2018 ~ 2024', '2014 ~ 2022',
#        '2018 ~ 2023', '2016 ~ 2023', '2013 ~ 2023', '2011 ~ 2023',
#        '2009 ~ 2022', '2005 ~ 2021', '2011 ~ 2021', '2015 ~ 2022',
#        '2017 ~ 2024', '2010 ~ 2024', '2012 ~ 2021', '2019 ~ 2024',
#        '2015 ~ 2024', '2017 ~ 2025', '2020 ~ 2025', '2019 ~ 2023',
#        '2008 ~ 2023', '2015 ~ 2021', '2020 ~ 2022', '2012 ~ 2022',
#        '2016 ~ 2025', '2013 ~ 2022', '2011 ~ 2022', '2012 ~ 2024',
#        '2016 ~ 2021', '2012 ~ 2023', '2008 ~ 2022', '2019 ~ 2022',
#        '2017 ~ 2021', '2013 ~ 2024', '2020 ~ 2024', '2010 ~ 2022',
#        '2020 ~ 2021', '2011 ~ 2024', '2020 ~ 2023', '2014 ~ 2024',
#        '2013 ~ 2026', '2016 ~ 2022', '2010 ~ 2021', '2013 ~ 2021',
#        '2019 ~ 2025', '2018 ~ 2025', '2016 ~ 2024', '2018 ~ 2021',
#        '2009 ~ 2024', '2007 ~ 2022', 'Jun 30, 2021 On Loan',
# ...

# %%
for index, row in fifa.iterrows():
    if 'Free' in row['Contract'] or 'On Loan' in row['Contract']:
        print(row['Contract'])
# Out:
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Free
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Free
# Free
# Free
# Free
# Free
# Free
# Free
# Free
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Free
# Free
# Free
# Jun 30, 2021 On Loan
# Dec 31, 2020 On Loan
# Jun 30, 2021 On Loan
# Free
# Jun 30, 2021 On Loan
# Free
# Free
# Free
# Free
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Jun 30, 2021 On Loan
# Free
# Jun 30, 2021 On Loan
# Jan 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Jun 30, 2021 On Loan
# Free
# Dec 31, 2020 On Loan
# Jun 30, 2021 On Loan
# ...

# %% [markdown]
# #### Extract the info from Contract column, then assigned into 3 new columns : Contract Start, Contract End, Contract Period (years)

# %%
# define a func to extract info from Contract column into 3 variables (to be assigned to 3 new columns later)

def extract_data(contract):

    if contract == 'Free' or 'On Loan' in contract:
        start_date = np.nan
        end_date = np.nan
        contract_period = 0
    else:
        start_date, end_date = contract.split(' ~ ')
        contract_period = int(end_date) - int(start_date)
    return start_date, end_date, contract_period

# define new columns
new_cols = ['Contract Start', 'Contract End', 'Contract Period (years)']
new_data = fifa['Contract'].apply(lambda x: pd.Series(extract_data(x)))

# create columns and insert data respectively

for i in range(len(new_cols)):
    fifa.insert(loc=fifa.columns.get_loc('Contract')+1+i, column=new_cols[i], value=new_data[i])

# %%
fifa[['Contract', 'Contract Start', 'Contract End', 'Contract Period (years)']].sample(10)
# Out:
#           Contract Contract Start Contract End  Contract Period (years)
# 7787          Free            NaN          NaN                      0.0
# 7770          Free            NaN          NaN                      0.0
# 10180  2020 ~ 2021           2020         2021                      1.0
# 8655   2019 ~ 2022           2019         2022                      3.0
# 13662  2019 ~ 2021           2019         2021                      2.0
# 1178   2016 ~ 2023           2016         2023                      7.0
# 12145  2019 ~ 2021           2019         2021                      2.0
# 9998   2016 ~ 2021           2016         2021                      5.0
# 870    2016 ~ 2021           2016         2021                      5.0
# 12603  2020 ~ 2020           2020         2020                      0.0

# %% [markdown]
# #### Categorize each Contract status into new column: Contract Status

# %%
def status(contract):
    if contract == 'Free':
        return 'Free'
    elif 'On Loan' in contract:
        return 'On Loan'
    else:
        return 'Contract'

contract_status = fifa['Contract'].apply(status)

# add contract status column

fifa.insert(fifa.columns.get_loc('Contract Period (years)')+1, 'Contract Status', contract_status)

# %%
fifa[['Contract', 'Contract Start', 'Contract End', 'Contract Period (years)', 'Contract Status']].sample(10)
# Out:
#                    Contract Contract Start Contract End  \
# 5079   Jun 30, 2021 On Loan            NaN          NaN
# 12042           2017 ~ 2021           2017         2021
# 300             2014 ~ 2023           2014         2023
# 14482           2017 ~ 2021           2017         2021
# 1258            2018 ~ 2021           2018         2021
# 16668           2019 ~ 2024           2019         2024
# 3926            2020 ~ 2021           2020         2021
# 1620            2017 ~ 2022           2017         2022
# 17115           2020 ~ 2021           2020         2021
# 3338            2016 ~ 2024           2016         2024
#
#        Contract Period (years) Contract Status
# 5079                       0.0         On Loan
# 12042                      4.0        Contract
# 300                        9.0        Contract
# 14482                      4.0        Contract
# 1258                       3.0        Contract
# 16668                      5.0        Contract
# ...

# %% [markdown]
# ### Height Column
#
# #### Convert feet and inches to cm.

# %%
fifa['Height'].unique()
# Out:
# array(['170cm', '187cm', '188cm', '181cm', '175cm', '184cm', '191cm',
#        '178cm', '193cm', '185cm', '199cm', '173cm', '168cm', '176cm',
#        '177cm', '183cm', '180cm', '189cm', '179cm', '195cm', '172cm',
#        '182cm', '186cm', '192cm', '165cm', '194cm', '167cm', '196cm',
#        '163cm', '190cm', '174cm', '169cm', '171cm', '197cm', '200cm',
#        '166cm', '6\'2"', '164cm', '198cm', '6\'3"', '6\'5"', '5\'11"',
#        '6\'4"', '6\'1"', '6\'0"', '5\'10"', '5\'9"', '5\'6"', '5\'7"',
#        '5\'4"', '201cm', '158cm', '162cm', '161cm', '160cm', '203cm',
#        '157cm', '156cm', '202cm', '159cm', '206cm', '155cm'], dtype=object)

# %%
def convert_height(height):
    if 'cm' in height:
        return int(height.strip('cm'))
    else:
        feet, inches = height.split("'")
        total_inches = int(feet)*12 + int(inches.strip('"'))
        return round(total_inches * 2.54)

fifa['Height'] = fifa['Height'].apply(convert_height)

# %%
fifa['Height'].unique()
# Out:
# array([170, 187, 188, 181, 175, 184, 191, 178, 193, 185, 199, 173, 168,
#        176, 177, 183, 180, 189, 179, 195, 172, 182, 186, 192, 165, 194,
#        167, 196, 163, 190, 174, 169, 171, 197, 200, 166, 164, 198, 201,
#        158, 162, 161, 160, 203, 157, 156, 202, 159, 206, 155])

# %% [markdown]
# #### Rename column to Height(cm).

# %%
fifa = fifa.rename(columns={'Height':'Height(cm)'})

# %%
fifa.head(1)
# Out:
#        ID      Name      LongName  \
# 0  158023  L. Messi  Lionel Messi
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
#
#    POT          Club     Contract Contract Start Contract End  \
# 0   93  FC Barcelona  2004 ~ 2021           2004         2021
#
#    Contract Period (years) Contract Status   Positions  Height(cm) Weight  \
# 0                     17.0        Contract  RW, ST, CF         170   72kg
#
#   Preferred Foot  BOV Best Position      Joined Loan Date End    Value   Wage  \
# 0           Left   93            RW  01/07/2004           NaN  €103.5M  €560K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0        €138.4M        429        85         95                70
#
# ...

# %% [markdown]
# ### Weight Column
#
# #### Convert pounds to kg.

# %%
fifa['Weight'].unique()
# Out:
# array(['72kg', '83kg', '87kg', '70kg', '68kg', '80kg', '71kg', '91kg',
#        '73kg', '85kg', '92kg', '69kg', '84kg', '96kg', '81kg', '82kg',
#        '75kg', '86kg', '89kg', '74kg', '76kg', '64kg', '78kg', '90kg',
#        '66kg', '60kg', '94kg', '79kg', '67kg', '65kg', '59kg', '61kg',
#        '93kg', '88kg', '97kg', '77kg', '62kg', '63kg', '95kg', '100kg',
#        '58kg', '183lbs', '179lbs', '172lbs', '196lbs', '176lbs', '185lbs',
#        '170lbs', '203lbs', '168lbs', '161lbs', '146lbs', '130lbs',
#        '190lbs', '174lbs', '148lbs', '165lbs', '159lbs', '192lbs',
#        '181lbs', '139lbs', '154lbs', '157lbs', '163lbs', '98kg', '103kg',
#        '99kg', '102kg', '56kg', '101kg', '57kg', '55kg', '104kg', '107kg',
#        '110kg', '53kg', '50kg', '54kg', '52kg'], dtype=object)

# %%
def convert_weight(weight):
    if "kg" in weight:
        return int(weight.strip("kg"))
    else:
        pounds = int(weight.strip('lbs'))
        return round(pounds / 2.205)

# apply func to Weight column

fifa['Weight']= fifa['Weight'].apply(convert_weight)

# %%
fifa['Weight'].unique()
# Out:
# array([ 72,  83,  87,  70,  68,  80,  71,  91,  73,  85,  92,  69,  84,
#         96,  81,  82,  75,  86,  89,  74,  76,  64,  78,  90,  66,  60,
#         94,  79,  67,  65,  59,  61,  93,  88,  97,  77,  62,  63,  95,
#        100,  58,  98, 103,  99, 102,  56, 101,  57,  55, 104, 107, 110,
#         53,  50,  54,  52])

# %% [markdown]
# #### Rename to Weight(kg)

# %%
fifa = fifa.rename(columns={'Weight':'Weight(kg)'})

# %%
fifa.head(1)
# Out:
#        ID      Name      LongName  \
# 0  158023  L. Messi  Lionel Messi
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
#
#    POT          Club     Contract Contract Start Contract End  \
# 0   93  FC Barcelona  2004 ~ 2021           2004         2021
#
#    Contract Period (years) Contract Status   Positions  Height(cm)  \
# 0                     17.0        Contract  RW, ST, CF         170
#
#    Weight(kg) Preferred Foot  BOV Best Position      Joined Loan Date End  \
# 0          72           Left   93            RW  01/07/2004           NaN
#
#      Value   Wage Release Clause  Attacking  Crossing  Finishing  \
# 0  €103.5M  €560K        €138.4M        429        85         95
#
#    Heading Accuracy  Short Passing  Volleys  Skill  Dribbling  Curve  \
# ...

# %% [markdown]
# ### Joined column
#
# #### Change the date format to dd/mm/yyyy.

# %%
fifa['Joined'].unique()
# Out:
# array(['01-Jul-04', '10-Jul-18', '16-Jul-14', ..., '22-Sep-18',
#        '28-Feb-15', '06-Mar-18'], dtype=object)

# %%
fifa['Joined'] = pd.to_datetime(fifa['Joined'], format="%d-%b-%y")

fifa['Joined'] = fifa['Joined'].dt.strftime("%d/%m/%Y")

fifa['Joined'].sample(50)
# Out:
# 3220     12/12/2016
# 4469     01/07/2014
# 6846     26/01/2018
# 5838     01/09/2020
# 2719     27/02/2020
# 5409     15/01/2020
# 0        01/07/2004
# 18196    12/06/2019
# 17211    01/01/2020
# 9865     15/01/2014
# 964      01/07/2019
# 17914    09/07/2017
# 8779     01/01/2019
# 8399     04/01/2019
# 8140     12/07/2019
# 3967     16/09/2020
# 15495    03/02/2020
# 1157     01/07/2016
# 5212     14/07/2016
# 15936    03/07/2019
# 7        19/07/2018
# 1818     01/10/2020
# 2891     01/07/2017
# 1578     01/01/2011
# 10006    05/01/2019
# 16377    01/07/2019
# 15108    01/01/2020
# 1859     16/08/2020
# 9275     05/01/2017
# 6487     22/07/2019
# 11629    21/08/2019
# 7589     01/03/2017
# 9412     15/01/2016
# 12448    22/11/2018
# 2371     01/07/2018
# 8578     08/01/2020
# 17887    01/02/2020
# 1298     05/10/2020
# 11912    02/09/2019
# 2424     01/01/2019
# 17344    08/02/2019
# 9532     31/01/2017
# 10708    02/01/2011
# 9498     05/01/2018
# 228      19/09/2020
# ...

# %% [markdown]
# ### Remove ★ in rating columns

# %% [markdown]
# #### W/F Column

# %%
fifa['W/F'].unique()
# Out:
# array(['4 ★', '3 ★', '5 ★', '2 ★', '1 ★'], dtype=object)

# %%
fifa['W/F'] = fifa['W/F'].str.replace(' ★', '')

# %%
fifa['W/F'].unique()
# Out:
# array(['4', '3', '5', '2', '1'], dtype=object)

# %% [markdown]
# #### SM Column

# %%
fifa['SM'].unique()
# Out:
# array(['4★', '5★', '1★', '2★', '3★'], dtype=object)

# %%
fifa['SM'] = fifa['SM'].str.replace('★', '')

# %%
fifa['SM'].unique()
# Out:
# array(['4', '5', '1', '2', '3'], dtype=object)

# %% [markdown]
# ### IR column

# %%
fifa['IR'].unique()
# Out:
# array(['5 ★', '3 ★', '4 ★', '2 ★', '1 ★'], dtype=object)

# %%
fifa['IR'] = fifa['IR'].str.replace(' ★', '')

# %%
fifa['IR'].unique()
# Out:
# array(['5', '3', '4', '2', '1'], dtype=object)

# %% [markdown]
# ### Checking Missing Values

# %% [markdown]
# #### Loan Date End Column

# %%
fifa['Loan Date End'].unique()
# Out:
# array([nan, '30-Jun-21', '31-Dec-20', '30-Jan-21', '30-Jun-22',
#        '31-May-21', '05-Jul-21', '31-Dec-21', '01-Jul-21', '01-Jan-21',
#        '31-Aug-21', '31-Jan-21', '30-Dec-21', '23-Jun-21', '03-Jan-21',
#        '27-Nov-21', '17-Jan-21', '30-Jun-23', '31-Jul-21', '22-Nov-20',
#        '31-May-22', '30-Dec-20', '04-Jan-21', '30-Nov-20', '01-Aug-21'],
#       dtype=object)

# %% [markdown]
# ##### This column represent the end date of loan for players who were 'On Loan'.
# ##### Therefore, players who were free and on contract, their records were blanks.

# %%
on_loan = fifa[fifa['Contract Status'] == 'On Loan']
on_loan[['Contract', 'Contract Status', 'Loan Date End']]
# Out:
#                    Contract Contract Status Loan Date End
# 205    Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 248    Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 254    Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 302    Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 306    Jun 30, 2021 On Loan         On Loan     30-Jun-21
# ...                     ...             ...           ...
# 18472  Aug 31, 2021 On Loan         On Loan     31-Aug-21
# 18571  Jun 30, 2021 On Loan         On Loan     30-Jun-21
# 18600  Dec 31, 2020 On Loan         On Loan     31-Dec-20
# 18622  Dec 31, 2020 On Loan         On Loan     31-Dec-20
# 18680  Dec 31, 2020 On Loan         On Loan     31-Dec-20
#
# [1013 rows x 3 columns]

# %% [markdown]
# #### Hits Column

# %% [markdown]
# ##### This column is the number of times the player has been searched for in the FIFA Ddatabase.
# ##### It is possible that there were players who have been not searched, which result in blank records.

# %%
fifa[ 'Hits']
# Out:
# 0        771
# 1        562
# 2        150
# 3        207
# 4        595
#         ...
# 18974    NaN
# 18975    NaN
# 18976    NaN
# 18977    NaN
# 18978    NaN
# Name: Hits, Length: 18979, dtype: object

# %%
fifa['Hits'].unique()
# Out:
# array(['771', '562', '150', '207', '595', '248', '246', '120', '1.6K',
#        '130', '321', '189', '175', '96', '118', '216', '212', '154',
#        '205', '202', '339', '408', '103', '332', '86', '173', '161',
#        '396', '1.1K', '433', '242', '206', '177', '1.5K', '198', '459',
#        '117', '119', '209', '84', '187', '165', '203', '65', '336', '126',
#        '313', '124', '145', '538', '182', '101', '45', '377', '99', '194',
#        '403', '414', '593', '374', '245', '3.2K', '266', '299', '309',
#        '215', '265', '211', '112', '337', '70', '159', '688', '116', '63',
#        '144', '123', '71', '224', '113', '168', '61', '89', '137', '278',
#        '75', '148', '176', '197', '264', '214', '247', '402', '440',
#        '1.7K', '2.3K', '171', '320', '657', '87', '259', '200', '255',
#        '253', '196', '60', '97', '85', '169', '256', '132', '239', '166',
#        '121', '109', '32', '46', '122', '48', '527', '199', '282', '51',
# ...
